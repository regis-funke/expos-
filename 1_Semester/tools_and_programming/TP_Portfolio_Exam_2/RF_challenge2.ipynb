# %% [markdown]
# # Python Challenge Part 2

# %% [markdown]
# # Guidelines
# - Only include the **answers to the posed questions** into this Notebook, not some additional analysis that you may have performed.
# - It is **not necessary to comment** the code or results, as long as they are correct and speak for themselves. However, commenting can sometimes be helpful to clarify why you take a particular approach, or in case you note that your results are not entirely correct.
# - Correct results can be obtained in many, different ways.
# - I will check your code, not only the output.
# - Follow-up errors are not counted as errors.
#
# # Data
# To solve the exercises you need the following two data files:
#
# - **charts.csv**: contains information on the top 200 songs per country and week
# - **songs.csv** contains song metadata

# %%
# Load packages here
import numpy as np
import pandas as pd

# %% [markdown]
# # Exercise 1 (15 Points)

# %% [markdown]
# **Exercise 1.1**
# - Read in the data sets `songs.csv`.
# - Display the first five observations.
# - Display the number of rows and columns.

# %%
songs = pd.read_csv('songs.csv')

# %%
# first five oberservations
songs.head(5)
# Out:
#                   song_id      artist_name                song_name  genre  \
# 0  00mBzIWv5gHOYxwuEJXjOG  December Avenue    Sa Ngalan Ng Pag-Ibig    pop
# 1  00tnXAltVLyIWok9sCWdjL      Dani Mocanu          Afaceri Ilegale  other
# 2  00x2d2mKSaUrCNTNxH7CYN            Sigma                     ALYX  other
# 3  011Xn3Wqii67s4aaPgheiu         Marteria  Love, Peace & Happiness    rap
# 4  014DA3BdnmD3kI5pBogH7c         Chillies            Cứ Chill Thôi  indie
#
#    duration_ms  explicit  danceability  loudness  speechiness  acousticness  \
# 0     285138.0     False         0.518    -3.907       0.0305        0.0851
# 1     176248.0     False         0.588    -4.680       0.3570        0.4000
# 2     167619.0      True         0.495   -10.033       0.3690        0.2800
# 3     213701.0     False         0.845    -7.397       0.1470        0.3040
# 4     270000.0     False         0.781    -8.452       0.0408        0.2170
#
#    instrumentalness valence
# 0          0.000000   0.271
# 1          0.000000   0.425
# 2          0.000000   0.368
# 3          0.000021   0.377
# 4          0.000036   0.609

# %%
songs.shape
# Out:
# (7388, 12)

# %% [markdown]
# **Exercise 1.2**
# - Read in the three data sets `charts.csv`.
# - Convert all column names into lower case letters.
# - Sort the charts DataFrame permanently by `chart_id` and `position`.
# - Display its first five rows.

# %%
# ingesting data
charts = pd.read_csv('charts.csv')

# turning column names into lower case
charts.columns = charts.columns.str.lower()

# %%
charts = charts.sort_values(by=['chart_id', 'position'], ascending=[True, True])


charts.head(5)
# Out:
#                             chart_id                 song_id  position  \
# 21565  regional-ae-weekly-2021-12-23  5PjdY0CKGZdEuoNab3yDmX       1.0
# 22740  regional-ae-weekly-2021-12-23  5Z9KJZvQzH6PFmb8SNkxuk       2.0
# 8368   regional-ae-weekly-2021-12-23  2Xr1dTzJee307rmrkt8c0g       3.0
# 17627  regional-ae-weekly-2021-12-23  02MWAaffLxlfxAUY7c5dvx       4.0
# 3830   regional-ae-weekly-2021-12-23  46IZ0fSY2mpAiktS3KOqds       5.0
#
#        streams
# 21565    63427
# 22740    56828
# 8368     55401
# 17627    53732
# 3830     50906

# %% [markdown]
# **Exercise 1.3**: Display the columns `song_name`, `artist_name`, and `danceability` of the 10 songs with the lowest danceability.

# %%
songs[['song_name', 'artist_name', 'danceability']].sort_values(by='danceability', ascending=True).head(10)
# Out:
#                                               song_name           artist_name  \
# 3504                                       Jólastjarnan          Memfismafían
# 5566  Intro to Fake News - from "Spider-Man: No Way ...     Michael Giacchino
# 1706                                       O Helga Natt             Nils Bech
# 484                               Can You Feel My Heart  Bring Me The Horizon
# 30               Have Yourself A Merry Little Christmas          Judy Garland
# 3428                                           Jolevise         Odd Nordstoga
# 3647                               No Child Left Behind            Kanye West
# 1772                                       Silent Night          Mariah Carey
# 120                            Nu tändas tusen juleljus                Carola
# 2220                              Sydämeeni joulun teen      Vesa-Matti Loiri
#
#       danceability
# 3504         0.141
# 5566         0.143
# 1706         0.145
# 484          0.150
# 30           0.156
# 3428         0.160
# 3647         0.161
# 1772         0.172
# 120          0.173
# 2220         0.175

# %% [markdown]
# **Exercise 1.4**: Calculate the average valence of all songs.

# %%
songs[['valence']].mean()
# Out:
# /var/folders/ng/wqc4d0qd0b92x6j5y4_0xzg80000gn/T/ipykernel_94419/2321584551.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   songs[['valence']].mean()
# Series([], dtype: float64)

# %% [markdown]
# # Exercise 2 (20 points)

# %% [markdown]
# **Exercise 2.1**:
# - Merge the two data sets, such that no observation of the charts gets lost.
# - Report the shape of the resulting data frame.

# %%
songs.head(5)
# Out:
#                   song_id      artist_name                song_name  genre  \
# 0  00mBzIWv5gHOYxwuEJXjOG  December Avenue    Sa Ngalan Ng Pag-Ibig    pop
# 1  00tnXAltVLyIWok9sCWdjL      Dani Mocanu          Afaceri Ilegale  other
# 2  00x2d2mKSaUrCNTNxH7CYN            Sigma                     ALYX  other
# 3  011Xn3Wqii67s4aaPgheiu         Marteria  Love, Peace & Happiness    rap
# 4  014DA3BdnmD3kI5pBogH7c         Chillies            Cứ Chill Thôi  indie
#
#    duration_ms  explicit  danceability  loudness  speechiness  acousticness  \
# 0     285138.0     False         0.518    -3.907       0.0305        0.0851
# 1     176248.0     False         0.588    -4.680       0.3570        0.4000
# 2     167619.0      True         0.495   -10.033       0.3690        0.2800
# 3     213701.0     False         0.845    -7.397       0.1470        0.3040
# 4     270000.0     False         0.781    -8.452       0.0408        0.2170
#
#    instrumentalness valence
# 0          0.000000   0.271
# 1          0.000000   0.425
# 2          0.000000   0.368
# 3          0.000021   0.377
# 4          0.000036   0.609

# %%
charts['song_id']=charts['song_id'].astype(str)
songs['song_id']=songs['song_id'].astype(str)

# %%
charts.columns = charts.columns.str.lower()
charts.head(5)
# Out:
#                             chart_id                 song_id  position  \
# 21565  regional-ae-weekly-2021-12-23  5PjdY0CKGZdEuoNab3yDmX       1.0
# 22740  regional-ae-weekly-2021-12-23  5Z9KJZvQzH6PFmb8SNkxuk       2.0
# 8368   regional-ae-weekly-2021-12-23  2Xr1dTzJee307rmrkt8c0g       3.0
# 17627  regional-ae-weekly-2021-12-23  02MWAaffLxlfxAUY7c5dvx       4.0
# 3830   regional-ae-weekly-2021-12-23  46IZ0fSY2mpAiktS3KOqds       5.0
#
#        streams
# 21565    63427
# 22740    56828
# 8368     55401
# 17627    53732
# 3830     50906

# %%
df = songs.merge(charts, how='left')
df.shape
# Out:
# (24318, 15)

# %% [markdown]
# **Exercse 2.2**:
#
# Report the number of observations...
#
# - whose merge key appears **in both the charts and the songs DataFrame**.
# - whose merge key appears **only in the charts DataFrame**.
# - whose merge key appears **only in the songs DataFrame**.
#
# Answer this question in a full sentence.

# %% [markdown]
# **Exercise 2.3**:
# - Create a new column `duration_min` that represents the duration of the song in minutes. This can be derived from `duration_ms`, which represents the duration in milliseconds.
# - Remove column `duration_ms`.
# - Report the column names.

# %%
df['duration_min'] = df['duration_ms']/60000

df = df.drop('duration_ms', 1)
# Out:
# /var/folders/ng/wqc4d0qd0b92x6j5y4_0xzg80000gn/T/ipykernel_94419/3406859895.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('duration_ms', 1)

# %%
df.columns
# Out:
# Index(['song_id', 'artist_name', 'song_name', 'genre', 'explicit',
#        'danceability', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'valence', 'chart_id', 'position', 'streams',
#        'duration_min'],
#       dtype='object')

# %% [markdown]
# **Exercise 2.4**:
#
# The variable `chart_id` contains information on several different aspects. For instance, `regional-de-weekly-2021-12-23` stands for the weekly, regional charts of the week 17-23 December 2021 for Germany.
#
# - Process the column `chart_id` such that you can create four new columns: `type`, `country`, `interval`, and (end) `date`.
# - Convert the column `date` as a datetime column.
# - Report the column `chart_id` and the four new columns for the first five rows of the data set.

# %%
df[['chart_id']].head()
# Out:
#                         chart_id
# 0  regional-ph-weekly-2021-12-23
# 1  regional-ro-weekly-2021-12-23
# 2  regional-gr-weekly-2021-12-23
# 3  regional-de-weekly-2021-10-21
# 4  regional-de-weekly-2021-10-28

# %%
df[['type', 'date']] = df['chart_id'].str.split('-', 1, expand=True)

# %%
df.head(5)
# Out:
#                   song_id      artist_name                song_name  genre  \
# 0  00mBzIWv5gHOYxwuEJXjOG  December Avenue    Sa Ngalan Ng Pag-Ibig    pop
# 1  00tnXAltVLyIWok9sCWdjL      Dani Mocanu          Afaceri Ilegale  other
# 2  00x2d2mKSaUrCNTNxH7CYN            Sigma                     ALYX  other
# 3  011Xn3Wqii67s4aaPgheiu         Marteria  Love, Peace & Happiness    rap
# 4  011Xn3Wqii67s4aaPgheiu         Marteria  Love, Peace & Happiness    rap
#
#    explicit  danceability  loudness  speechiness  acousticness  \
# 0     False         0.518    -3.907       0.0305        0.0851
# 1     False         0.588    -4.680       0.3570        0.4000
# 2      True         0.495   -10.033       0.3690        0.2800
# 3     False         0.845    -7.397       0.1470        0.3040
# 4     False         0.845    -7.397       0.1470        0.3040
#
#    instrumentalness valence                       chart_id  position  \
# 0          0.000000   0.271  regional-ph-weekly-2021-12-23     165.0
# 1          0.000000   0.425  regional-ro-weekly-2021-12-23     173.0
# 2          0.000000   0.368  regional-gr-weekly-2021-12-23     179.0
# 3          0.000021   0.377  regional-de-weekly-2021-10-21      87.0
# 4          0.000021   0.377  regional-de-weekly-2021-10-28     145.0
#
#     streams  duration_min      type                  date
# 0  229235.0      4.752300  regional  ph-weekly-2021-12-23
# 1   21278.0      2.937467  regional  ro-weekly-2021-12-23
# 2   33640.0      2.793650  regional  gr-weekly-2021-12-23
# 3  590676.0      3.561683  regional  de-weekly-2021-10-21
# 4  438666.0      3.561683  regional  de-weekly-2021-10-28

# %%
df[['country', 'interval']] = df['date'].str.split('-', 1, expand=True)
df.head(5)
# Out:
#                   song_id      artist_name                song_name  genre  \
# 0  00mBzIWv5gHOYxwuEJXjOG  December Avenue    Sa Ngalan Ng Pag-Ibig    pop
# 1  00tnXAltVLyIWok9sCWdjL      Dani Mocanu          Afaceri Ilegale  other
# 2  00x2d2mKSaUrCNTNxH7CYN            Sigma                     ALYX  other
# 3  011Xn3Wqii67s4aaPgheiu         Marteria  Love, Peace & Happiness    rap
# 4  011Xn3Wqii67s4aaPgheiu         Marteria  Love, Peace & Happiness    rap
#
#    explicit  danceability  loudness  speechiness  acousticness  \
# 0     False         0.518    -3.907       0.0305        0.0851
# 1     False         0.588    -4.680       0.3570        0.4000
# 2      True         0.495   -10.033       0.3690        0.2800
# 3     False         0.845    -7.397       0.1470        0.3040
# 4     False         0.845    -7.397       0.1470        0.3040
#
#    instrumentalness valence                       chart_id  position  \
# 0          0.000000   0.271  regional-ph-weekly-2021-12-23     165.0
# 1          0.000000   0.425  regional-ro-weekly-2021-12-23     173.0
# 2          0.000000   0.368  regional-gr-weekly-2021-12-23     179.0
# 3          0.000021   0.377  regional-de-weekly-2021-10-21      87.0
# 4          0.000021   0.377  regional-de-weekly-2021-10-28     145.0
#
#     streams  duration_min      type                  date country  \
# 0  229235.0      4.752300  regional  ph-weekly-2021-12-23      ph
# 1   21278.0      2.937467  regional  ro-weekly-2021-12-23      ro
# 2   33640.0      2.793650  regional  gr-weekly-2021-12-23      gr
# 3  590676.0      3.561683  regional  de-weekly-2021-10-21      de
# 4  438666.0      3.561683  regional  de-weekly-2021-10-28      de
#
#             interval
# 0  weekly-2021-12-23
# 1  weekly-2021-12-23
# 2  weekly-2021-12-23
# 3  weekly-2021-10-21
# 4  weekly-2021-10-28

# %%
df[['interval', 'date']] = df['interval'].str.split('-', 1, expand=True)
df.head(5)
# Out:
#                   song_id      artist_name                song_name  genre  \
# 0  00mBzIWv5gHOYxwuEJXjOG  December Avenue    Sa Ngalan Ng Pag-Ibig    pop
# 1  00tnXAltVLyIWok9sCWdjL      Dani Mocanu          Afaceri Ilegale  other
# 2  00x2d2mKSaUrCNTNxH7CYN            Sigma                     ALYX  other
# 3  011Xn3Wqii67s4aaPgheiu         Marteria  Love, Peace & Happiness    rap
# 4  011Xn3Wqii67s4aaPgheiu         Marteria  Love, Peace & Happiness    rap
#
#    explicit  danceability  loudness  speechiness  acousticness  \
# 0     False         0.518    -3.907       0.0305        0.0851
# 1     False         0.588    -4.680       0.3570        0.4000
# 2      True         0.495   -10.033       0.3690        0.2800
# 3     False         0.845    -7.397       0.1470        0.3040
# 4     False         0.845    -7.397       0.1470        0.3040
#
#    instrumentalness valence                       chart_id  position  \
# 0          0.000000   0.271  regional-ph-weekly-2021-12-23     165.0
# 1          0.000000   0.425  regional-ro-weekly-2021-12-23     173.0
# 2          0.000000   0.368  regional-gr-weekly-2021-12-23     179.0
# 3          0.000021   0.377  regional-de-weekly-2021-10-21      87.0
# 4          0.000021   0.377  regional-de-weekly-2021-10-28     145.0
#
#     streams  duration_min      type        date country interval
# 0  229235.0      4.752300  regional  2021-12-23      ph   weekly
# 1   21278.0      2.937467  regional  2021-12-23      ro   weekly
# 2   33640.0      2.793650  regional  2021-12-23      gr   weekly
# 3  590676.0      3.561683  regional  2021-10-21      de   weekly
# 4  438666.0      3.561683  regional  2021-10-28      de   weekly

# %% [markdown]
# # Exercise 3 (20 points)

# %% [markdown]
# **Exercise 3.1**: Consider the charts of the week prior to christmas (date: 2021-12-23). How many songs that appeared in the German (de) charts during this week also appear in the charts of the Unites States (us)?

# %%
df[['date']] > '2021-12-23'
# Out:
#         date
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 24313  False
# 24314  False
# 24315  False
# 24316  False
# 24317  False
#
# [24318 rows x 1 columns]

# %% [markdown]
# **Exercise 3.2**: The boolean variable `explicit` indicates whether a song contains content that is inappropriate for children (True), or not (False).
#
# - Calculate for each `genre` what fraction of songs are classified as `explicit`, as well as the number of non-missing observations for the variable `explicit`.
# - Display the resulting DataFrame, sorted from most explicit to least explicit.

# %%
df1 = df[['genre', 'explicit']].groupby('explicit')
df1

# %%
df[['explicit']]
# Out:
#        explicit
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
# ...         ...
# 24313     False
# 24314     False
# 24315     False
# 24316     False
# 24317     False
#
# [24318 rows x 1 columns]

# %% [markdown]
# **Exercise 3.3** Display all the names of artists that perform a song with the song name "Last Christmas"?

# %%
df[['song_name']] == 'Last Christmas'
# Out:
#        song_name
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 24313      False
# 24314      False
# 24315      False
# 24316      False
# 24317      False
#
# [24318 rows x 1 columns]

# %% [markdown]
# **Exercise 3.4**: Create a visulization that contains 2 subplots:
#
# - A bar plot that shows the total number of streams per genre for Mexico (mx)
# - A bar plot that shows the total number of streams per genre for United States (us)
# - Both subplots should contain title and axis titles. Also, the overall figure should contain a title.

# %%
'streams' 'mx'
# Out:
# 'streamsmx'

# %%
import plotly.express as px

px.bar(df, x=df['genre'], y=df['streams'])
